# %% [markdown]
# <center>
# <img src="https://cdn.megabonus.com/images/shop_logo/skillbox.png"/>
#
# # Курс аналитик данных на Python
# ## Модуль 3.1. Pandas advanced. Составляем отчетность.

# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# Итак, в этом уроке мы попробуем решить совсем прикладную задачу и научимся работать с табличными данными.<br>
# А именно:
# * узнаем как работать с файлом, который весит **30+ мегабайт**.;
# * посчитаем **базовые статистики** в разных **разрезах и сегментах пользователей** и **уберем выбросы**;
# * поймем **как объединить таблицы** по ключу;
# * оформим **отчет по среднему чеку по дате и в разрезе категорий** и **отчет по оттоку пользователей**;
# * сделаем **отдельную функцию для отправления на почту**;
# <br>
# Но обо всем по порядку!

# %% [markdown]
# Для начала прочитаем данные с помощью библиотеки [**pandas**](http://pandas.pydata.org/pandas-docs/stable/).<br>
# Наши довольно большие. Таблица более миллиона строк и в распакованном виде весит около **30 мб**<br>
# Это не так много, но вопрос сколько времени excel это будет читать оставляю вам на размышление)

# %% [markdown]
# ## 1. Загрузим наш файл.

# %%
data = pd.read_csv('data.csv.gz', compression='gzip')

# %% [markdown]
# Как и прежде, первое с чего нужно начать это с того чтобы понять что перел нами за данные.<br>
# Посмотрим на количество строк, колонки и типы данных. Также заметим что в распакованном виде наши **данные раздулись до 53+ мб**.

# %%
print('У нас %s строк и %s колонок.'%data.shape)
print('---')
print(data.info())
# Out:
# У нас 1008889 строк и 8 колонок.
# ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008889 entries, 0 to 1008888
# Data columns (total 8 columns):
# mcc             1008889 non-null int64
# period          1008889 non-null object
# trdatetime      1008889 non-null object
# amount          1008889 non-null float64
# channel_type    1003825 non-null object
# cl_id           1008889 non-null int64
# currency        1008889 non-null int64
# trx_category    1008889 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 61.6+ MB
# None

# %%
data.describe()
# Out:
#                 mcc        amount         cl_id      currency
# count  1.008889e+06  1.008889e+06  1.008889e+06  1.008889e+06
# mean   5.695758e+03  5.613910e+03  4.792338e+03  8.106325e+02
# std    6.629852e+02  6.258510e+04  2.956989e+03  3.869616e+01
# min    7.420000e+02  1.000000e-02  0.000000e+00  3.200000e+01
# 25%    5.411000e+03  2.200000e+02  2.184000e+03  8.100000e+02
# 50%    5.661000e+03  6.162000e+02  4.586000e+03  8.100000e+02
# 75%    5.941000e+03  2.147000e+03  7.350000e+03  8.100000e+02
# max    9.405000e+03  3.583500e+07  1.021600e+04  9.860000e+02

# %% [markdown]
# И посмотрим на первые 3 строчки.

# %%
data.head(3)
# Out:
#     mcc      period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200  01/10/2017  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011  01/10/2017  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921  01/12/2017  05DEC17:00:00:00    767.0          NaN      0       810
#
#   trx_category
# 0          POS
# 1      DEPOSIT
# 2          POS

# %% [markdown]
# Сразу можно заметить, что у нас транзакционный датасет. Так как это реальные данные, то некоторые поля заменяются приватными значения, как например тут категория валюты.<br>

# %% [markdown]
# Мы можем посчитать сколько унас валют всего, чтобы понять масштабы.

# %%
len(data['currency'].unique())
# Out:
# array([810, 978, 504, 704, 981, 985, 840, 949,  51, 826, 214, 764, 203,
#        702, 360, 756, 933, 975,  36, 191, 784, 980, 124, 398, 376, 944,
#        352, 417, 156, 752, 392, 484, 634, 188, 643, 348, 356, 458, 986,
#        498, 578, 208, 344,  32, 410, 788, 480, 604, 941, 144, 946, 710,
#        690,  44, 170, 901, 608, 554, 462, 800, 977, 496, 516,  48, 446,
#        404, 524], dtype=int64)

# %% [markdown]
# И посмотреть что у нас за категории. Смутно можно понять, что они связаны с типом транзакции, например <br>
# `WD_ATM_PARTNER` это снятие с банкомата партнера, а `POS` это потребительский кредит, тоесть оплата с кредитной карты.

# %%
data.trx_category.unique()
# Out:
# array(['POS', 'DEPOSIT', 'C2C_OUT', 'WD_ATM_ROS', 'BACK_TRX',
#        'WD_ATM_PARTNER', 'WD_ATM_OTHER', 'C2C_IN', 'CAT', 'CASH_ADV'],
#       dtype=object)

# %%
data.head()
# Out:
#     mcc      period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200  01/10/2017  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011  01/10/2017  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921  01/12/2017  05DEC17:00:00:00    767.0          NaN      0       810
# 3  5411  01/10/2017  21OCT17:00:00:00   2031.0          NaN      0       810
# 4  6012  01/10/2017  24OCT17:13:14:24  36562.0          NaN      0       810
#
#   trx_category
# 0          POS
# 1      DEPOSIT
# 2          POS
# 3          POS
# 4      C2C_OUT

# %% [markdown]
# Сразу бросается в глаза дата транзакции и ее формат, поэтому давайте приведем ее в нормальный вид.<br>
# А так же отдельные колонки для года/месяца/дня/времени и соединим месяц с годом, для удобства <br>
# (так как у нас данные за несколько лет), чтобы потом сделать помесячные отчеты.<br>
# Чтобы не потерять и не испортить данные, лучше делать отдельные колонки.

# %%
# преобразование даты
data['period'] = pd.to_datetime(data['period'], format='%d/%m/%Y')

# преобразование времени
data['transac_time'] = data['trdatetime'].str[-11:-3]

# разные компоненты даты по столбцам
data['transac_day'] = data['trdatetime'].str[:2]
month_dict={'JAN':'01', 'FEB':'02', 'MAR':'03', 'APR':'04', 'MAY':'05', 'JUN':'06', 
            'JUL':'07', 'AUG':'08', 'SEP':'09', 'OCT':'10', 'NOV':'11', 'DEC':'12'}
data['transac_month'] = data['trdatetime'].str[2:5].map(month_dict)
data['transac_year'] = '20'+data['trdatetime'].str[5:7]

# комбинированное поле месяц-год
#data['transac_year_month'] = data['period'].apply(lambda x: x.strftime('%m-%Y')) 
data['transac_year_month'] = '20'+data['trdatetime'].str[5:7]+'-'+data['trdatetime'].str[2:5].map(month_dict)

# %%
data.head(3)
# Out:
#     mcc     period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200 2017-10-01  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011 2017-10-01  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921 2017-12-01  05DEC17:00:00:00    767.0          NaN      0       810
#
#   trx_category transac_time transac_day transac_month transac_year  \
# 0          POS     17:00:00          21            10         2017
# 1      DEPOSIT     17:12:24          12            10         2017
# 2          POS     17:00:00          05            12         2017
#
#   transac_year_month
# 0            2017-10
# 1            2017-10
# 2            2017-12

# %% [markdown]
# Отлично, давайте теперь посмотрим на экстримальные значения наших транзакций.

# %%
data.groupby('currency')['amount'].agg(['min', 'mean', 'median','max']).tail()
# Out:
#            min        mean  median       max
# currency
# 978       0.01  105.797974   29.00   9690.00
# 980       1.50  885.639098  282.00  15451.17
# 981       0.80   94.718251   35.62   1306.00
# 985       0.99  101.715674   35.67   4800.00
# 986       6.00   88.106471   60.00    260.00

# %% [markdown]
# Ок, но не ясно что за валюты, может где-то можно найти соотвествие числовых кодов и хотябы привычных<br>
# трехбуквенных кодов вида **USD**, **EUR**, **RUB**?

# %% [markdown]
# ## 2. Расшифруем валютные коды.

# %%
wiki_table = pd.read_csv('currency_codes_wiki.csv')
wiki_table.head()
# Out:
#    num_code currency_code                          title
# 0       784           AED    United Arab Emirates dirham
# 1       971           AFN                 Afghan afghani
# 2         8           ALL                   Albanian lek
# 3        51           AMD                  Armenian dram
# 4       532           ANG  Netherlands Antillean guilder

# %%
wiki_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 3 columns):
# num_code         178 non-null int64
# currency_code    178 non-null object
# title            177 non-null object
# dtypes: int64(1), object(2)
# memory usage: 4.2+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008889 entries, 0 to 1008888
# Data columns (total 13 columns):
# mcc                   1008889 non-null int64
# period                1008889 non-null datetime64[ns]
# trdatetime            1008889 non-null object
# amount                1008889 non-null float64
# channel_type          1003825 non-null object
# cl_id                 1008889 non-null int64
# currency              1008889 non-null int64
# trx_category          1008889 non-null object
# transac_time          1008889 non-null object
# transac_day           1008889 non-null object
# transac_month         1008889 non-null object
# transac_year          1008889 non-null object
# transac_year_month    1008889 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(8)
# memory usage: 100.1+ MB

# %% [markdown]
# Переведем наши поля по которым будем мэтчить в один тип данных. Я выбрал `int`.<br>
# Приводить значения в таблице `wiki_table` нам не надо так как они уже в `int`.

# %%
#wiki_table['num_code'] = wiki_table['num_code'].astype(int)
data['currency'] = data['currency'].astype(int)

# %% [markdown]
# Чтобы совместить таблички нам нужно их "смерджить", то есть применить метод **.merge**, который дословно значит "слить".<br>
# Итак, смерджить таблички можно по-разному, как схематически показано ниже. И в зависимости от смысла задачи может требоваться <br>
# разный вид мерджа. В нашем случае нам нужен левый (left), чтобы притянуть все значения к левой табличке.<br>
# Про объединение таблиц и различного рода совмещения очень хорошо написано с примерами в [документации](https://pandas.pydata.org/pandas-docs/stable/merging.html).
# <img src="https://shanelynnwebsite-mid9n9g1q9y8tt.netdna-ssl.com/wp-content/uploads/2017/03/join-types-merge-names.jpg"/>

# %%
data.merge(wiki_table, left_on='currency', right_on='num_code', how='left').head()
# Out:
#     mcc     period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200 2017-10-01  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011 2017-10-01  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921 2017-12-01  05DEC17:00:00:00    767.0          NaN      0       810
# 3  5411 2017-10-01  21OCT17:00:00:00   2031.0          NaN      0       810
# 4  6012 2017-10-01  24OCT17:13:14:24  36562.0          NaN      0       810
#
#   trx_category transac_time transac_day transac_month transac_year  \
# 0          POS     17:00:00          21            10         2017
# 1      DEPOSIT     17:12:24          12            10         2017
# 2          POS     17:00:00          05            12         2017
# 3          POS     17:00:00          21            10         2017
# 4      C2C_OUT     17:13:14          24            10         2017
#
#   transac_year_month  num_code currency_code title
# 0            2017-10       NaN           NaN   NaN
# 1            2017-10       NaN           NaN   NaN
# 2            2017-12       NaN           NaN   NaN
# 3            2017-10       NaN           NaN   NaN
# 4            2017-10       NaN           NaN   NaN

# %% [markdown]
# **WAT DA HELL?**

# %% [markdown]
# Хух, ну вроде все верно, но что не так?

# %%
data.merge(wiki_table, left_on='currency', right_on='num_code', how='left')['num_code'].unique()
# Out:
# array([ nan, 978., 504., 704., 981., 985., 840., 949.,  51., 826., 214.,
#        764., 203., 702., 360., 756., 933., 975.,  36., 191., 784., 980.,
#        124., 398., 376., 944., 352., 417., 156., 752., 392., 484., 634.,
#        188., 643., 348., 356., 458., 986., 498., 578., 208., 344.,  32.,
#        410., 788., 480., 604., 941., 144., 946., 710., 690.,  44., 170.,
#        901., 608., 554., 462., 800., 977., 496., 516.,  48., 446., 404.,
#        524.])

# %% [markdown]
# Дело в том, что в российских банках транзакции учитываюсь с кодом 810, который был введен **еще до деноминации 1998 года.** <br>
# <center>
# <img src="https://cs5.pikabu.ru/post_img/2015/12/04/5/1449210847155432089.jpg"/>
#
# А в международном стандарте у России код: 643, что мы и можем видеть в таблице ниже.<br>
# Внутренний код для платежей в рублях до сих пор 810, что немного смущет, если честно.<br>
# Вокруг этого ходит довольно много баек и мифов, но с другой стороны, по сути это всего лишь дирекция ЦБ России <br>
# и присутствие того или иного кода в платежке ни на что не влияет существенным образом.<br>
# Тем не менее, кому интересно, больше можно почитать [тут](https://goo.gl/Jb5rQG) и конкретно [тут](https://fincult.info/articles/valyuty/mify-i-pravda-o-valyutnykh-kodakh-rublya/).<br>
# Но вернемся к делу!

# %%
wiki_table[wiki_table['title'] == 'Russian ruble']
# Out:
#      num_code currency_code          title
# 120       643           RUB  Russian ruble

# %%
wiki_table[wiki_table['title'].isin(["United States dollar","Afghan afghani"])]
# Out:
#      num_code currency_code                 title
# 1         971           AFN        Afghan afghani
# 148       840           USD  United States dollar

# %% [markdown]
# Поправим немного нашу таблицу, чтобы мы могли классифицировать наши транзакции полностью.

# %%
wiki_table = wiki_table.append({'num_code': 810, 'currency_code':'RUR','title':'Russian ruble'},ignore_index=True)

# %% [markdown]
# В этот раз сохраним наши измениея, переназначив объект.

# %%
data = data.merge(wiki_table, left_on='currency', right_on='num_code', how='left')
data.head()
# Out:
#     mcc     period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200 2017-10-01  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011 2017-10-01  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921 2017-12-01  05DEC17:00:00:00    767.0          NaN      0       810
# 3  5411 2017-10-01  21OCT17:00:00:00   2031.0          NaN      0       810
# 4  6012 2017-10-01  24OCT17:13:14:24  36562.0          NaN      0       810
#
#   trx_category transac_time transac_day transac_month transac_year  \
# 0          POS     17:00:00          21            10         2017
# 1      DEPOSIT     17:12:24          12            10         2017
# 2          POS     17:00:00          05            12         2017
# 3          POS     17:00:00          21            10         2017
# 4      C2C_OUT     17:13:14          24            10         2017
#
#   transac_year_month  num_code currency_code          title
# 0            2017-10       810           RUR  Russian ruble
# 1            2017-10       810           RUR  Russian ruble
# 2            2017-12       810           RUR  Russian ruble
# 3            2017-10       810           RUR  Russian ruble
# 4            2017-10       810           RUR  Russian ruble

# %% [markdown]
# Вот теперь совсем все хорошо и у нас все транзакции размечены нормальными названиями валют в которых они были совершены.
# Напомню, что числовы коды у нас типа `int`.

# %%
data[data['num_code'] == 810].head(3)
# Out:
#     mcc     period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200 2017-10-01  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011 2017-10-01  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921 2017-12-01  05DEC17:00:00:00    767.0          NaN      0       810
#
#   trx_category transac_time transac_day transac_month transac_year  \
# 0          POS     17:00:00          21            10         2017
# 1      DEPOSIT     17:12:24          12            10         2017
# 2          POS     17:00:00          05            12         2017
#
#   transac_year_month  num_code currency_code          title
# 0            2017-10       810           RUR  Russian ruble
# 1            2017-10       810           RUR  Russian ruble
# 2            2017-12       810           RUR  Russian ruble

# %% [markdown]
# Пропусков нет! Мы разметили все транзакции.

# %%
data['title'].isna().value_counts()
# Out:
# False    1008889
# Name: title, dtype: int64

# %% [markdown]
# Вернемся к нашей сгруппированной табличке.

# %%
data.groupby('title')['amount'].agg(['min', 'mean', 'median','max']).tail()
# Out:
#                                    min          mean     median          max
# title
# Ugandan shilling             855000.00  8.550000e+05  855000.00    855000.00
# Ukrainian hryvnia                 1.50  8.856391e+02     282.00     15451.17
# United Arab Emirates dirham       2.00  4.905544e+02      96.00     24704.40
# United States dollar              0.01  1.735173e+02      34.49     50000.00
# Vietnamese đồng               10700.00  1.806074e+06  757500.00  35835000.00

# %% [markdown]
# И сделаем её немного читабельнее.<br>
# Стоит заметить, что сортировка происходит по индексу, так что в случае с числовым кодом и названием валюты у нас <br>
# будет разный порядок.

# %%
data.groupby('title')['amount'].agg(['min', 'mean', 'median','max']).tail().apply(lambda x:round(x,0))
# Out:
#                                   min       mean    median         max
# title
# Ugandan shilling             855000.0   855000.0  855000.0    855000.0
# Ukrainian hryvnia                 2.0      886.0     282.0     15451.0
# United Arab Emirates dirham       2.0      491.0      96.0     24704.0
# United States dollar              0.0      174.0      34.0     50000.0
# Vietnamese đồng               10700.0  1806074.0  757500.0  35835000.0

# %%
data[(data['num_code'].isin([840,978]))].groupby('title')["amount"].mean()
# Out:
# title
# Euro                    105.797974
# United States dollar    173.517300
# Name: amount, dtype: float64

# %% [markdown]
# ## 3. Расшифруем MCC коды.

# %% [markdown]
# Также в интренете можно найти информаци о [MCC](https://en.wikipedia.org/wiki/Merchant_category_code). Это стандартизированный код категории покупки, который устанавливается на кассы предприятия. Потом банки исходя из этих кодов могут начислять кэшбек или бонусы за проведенные транзакции, если это предуматривает Ваш тариф. Имея текстовые репрезентации этих кодов довольно сильно поможет нам при построении осмысленного отчета.<br>
#
# У нас есть табличка с различными mcc кодами и их интерпритацией, которую я просто нагуглил.

# %%
mcc = pd.read_excel('mcc_codes.xls')

# %%
mcc.head()
# Out:
#   STANDARD MERCHANT CATEGORY CODES\n**Please do not sort this spreadsheet**  \
# 0                                           MCC CODE
# 1                                               0742
# 2                                               0763
# 3                                               0780
# 4                                               1520
#
#                                 Unnamed: 1 Unnamed: 2
# 0                            Program Type:        NaN
# 1                      Veterinary Services        NaN
# 2                Agricultural Cooperatives        NaN
# 3   Landscaping and Horticultural Services        NaN
# 4  General Contractor/Residential Building        NaN

# %% [markdown]
# Очень часто бывае что эксель попадает в таком виде. Чтобы получить красивую табличку нужно пропустить первый ряд и убрать правую колонку с пустыми значениями. Так и сделаем:

# %%
mcc = pd.read_excel('mcc_codes.xls',skiprows=1)
mcc = mcc.iloc[:,:-1]
mcc.head()
# Out:
#    MCC CODE                                    Program Type:
# 0     742.0                              Veterinary Services
# 1     763.0                        Agricultural Cooperatives
# 2     780.0           Landscaping and Horticultural Services
# 3    1520.0          General Contractor/Residential Building
# 4    1711.0  Heating, Plumbing, Air Conditioning Contractors

# %% [markdown]
# И переименуем колонки для красоты и удобства.

# %%
mcc = mcc.rename(columns={'MCC CODE':'mcc','Program Type:':'category'})

# %%
mcc.head()
# Out:
#       mcc                                         category
# 0   742.0                              Veterinary Services
# 1   763.0                        Agricultural Cooperatives
# 2   780.0           Landscaping and Horticultural Services
# 3  1520.0          General Contractor/Residential Building
# 4  1711.0  Heating, Plumbing, Air Conditioning Contractors

# %% [markdown]
# Объедним по категории к нашей общей таблице (левый мердж). <br>

# %%
data = data.merge(mcc, on='mcc', how='left')

# %%
data.head(3)
# Out:
#     mcc     period        trdatetime   amount channel_type  cl_id  currency  \
# 0  5200 2017-10-01  21OCT17:00:00:00   5023.0          NaN      0       810
# 1  6011 2017-10-01  12OCT17:12:24:07  20000.0          NaN      0       810
# 2  5921 2017-12-01  05DEC17:00:00:00    767.0          NaN      0       810
#
#   trx_category transac_time transac_day transac_month transac_year  \
# 0          POS     17:00:00          21            10         2017
# 1      DEPOSIT     17:12:24          12            10         2017
# 2          POS     17:00:00          05            12         2017
#
#   transac_year_month  num_code currency_code          title  \
# 0            2017-10       810           RUR  Russian ruble
# 1            2017-10       810           RUR  Russian ruble
# 2            2017-12       810           RUR  Russian ruble
#
#                                             category
# 0                              Home Supply Warehouse
# 1  Financial Institutions--Automated Cash Disburs...
# 2             Package Stores--Beer, Wine, and Liquor

# %% [markdown]
# Проверим сколько у нас категорий не подтянулось с помощью методов **.isna()** и **.value_counts()**.

# %%
data.category.isna().value_counts()
# Out:
# False    1008888
# True           1
# Name: category, dtype: int64

# %%
data.mcc.isna().value_counts()
# Out:
# False    1008889
# Name: mcc, dtype: int64

# %% [markdown]
# Действительно, в силу тех или иных причин мы не смогли индифицировать всего лишь 1 код, так что мы можем этим пренебречь.

# %% [markdown]
# ## 4.  Отчет по средним тратам.

# %% [markdown]
# Давайте уже построим отчет! Для этих целей отберем только рублевые транзакции и сделаем табличку в разрезе категория-даты.<br>
#
# Также, тк природа данных это покупки/транзакции, то присутствуют экстримальные значения, которые будут искажать среднее по больнице.
# Поэтому мы **отбросим по 5% максимальных значений и столько же минимальных**. Это называется **очисткой от выбросов** и для этого нам понадобится посчитать квартили и применить фильтрацию.

# %%
report = pd.DataFrame()
currency = 810
rubbles = data[data['currency'] == currency]
dates = sorted(rubbles['transac_year_month'].unique())


for date in dates:
    buffer = rubbles[rubbles['transac_year_month'] == date][['transac_year_month','amount','category']].set_index(['transac_year_month','category'])

    low = .05
    high = .95
    quant_df = buffer.quantile([low, high])

    filtered_df = buffer.apply(lambda x: x[(x>quant_df.loc[low,x.name]) & (x < quant_df.loc[high,x.name])], axis=0)
    filtered_df = filtered_df.reset_index().groupby(['transac_year_month','category']).mean()

    report = pd.concat([report, filtered_df]) # объединяем нашу таблицу

report = report.unstack().T # разворачиваем нашу таблицу 
report = round(report,2)

# %%
report.head()
# Out:
# transac_year_month                                       2016-10   2016-11  \
#        category
# amount AIR STANA                                             NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services        NaN   2294.42
#        Advertising Services                              1306.57   2674.30
#        AeroFlot                                         20423.09  12961.51
#        Agricultural Cooperatives                             NaN       NaN
#
# transac_year_month                                       2016-12   2017-01  \
#        category
# amount AIR STANA                                             NaN  14061.00
#        Accounting, Auditing, and Bookkeeping Services        NaN    960.00
#        Advertising Services                              1863.58   1367.67
#        AeroFlot                                         13992.32   8480.99
#        Agricultural Cooperatives                             NaN    702.00
#
# transac_year_month                                       2017-02   2017-03  \
#        category
# amount AIR STANA                                        10977.00       NaN
#        Accounting, Auditing, and Bookkeeping Services        NaN       NaN
#        Advertising Services                              1071.13   1117.51
#        AeroFlot                                          9766.56  11490.96
#        Agricultural Cooperatives                          624.00       NaN
#
# transac_year_month                                      2017-04  2017-05  \
#        category
# amount AIR STANA                                            NaN      NaN
#        Accounting, Auditing, and Bookkeeping Services       NaN   290.00
#        Advertising Services                             1783.02  1130.19
#        AeroFlot                                         9601.84  8756.14
#        Agricultural Cooperatives                        1879.50  1440.00
#
# transac_year_month                                       2017-06   2017-07  \
#        category
# amount AIR STANA                                        14092.00  11113.67
#        Accounting, Auditing, and Bookkeeping Services        NaN       NaN
#        Advertising Services                              1490.12   2049.76
#        AeroFlot                                         10632.52   9061.11
#        Agricultural Cooperatives                         1531.50       NaN
#
# transac_year_month                                       2017-08  2017-09  \
#        category
# amount AIR STANA                                        10691.00      NaN
#        Accounting, Auditing, and Bookkeeping Services        NaN   720.00
#        Advertising Services                              1517.03  1700.32
#        AeroFlot                                         10445.11  9230.78
#        Agricultural Cooperatives                             NaN   174.00
#
# transac_year_month                                      2017-10   2017-11  \
#        category
# amount AIR STANA                                            NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services       NaN       NaN
#        Advertising Services                             2955.57    533.81
#        AeroFlot                                         9766.24  16065.27
#        Agricultural Cooperatives                            NaN       NaN
#
# transac_year_month                                       2017-12   2018-01  \
#        category
# amount AIR STANA                                             NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services        NaN       NaN
#        Advertising Services                               191.31    293.31
#        AeroFlot                                         11272.70  12295.00
#        Agricultural Cooperatives                             NaN       NaN
#
# transac_year_month                                       2018-02  2018-03  \
#        category
# amount AIR STANA                                             NaN      NaN
#        Accounting, Auditing, and Bookkeeping Services        NaN      NaN
#        Advertising Services                               339.00   339.64
#        AeroFlot                                         11299.33  7031.71
#        Agricultural Cooperatives                             NaN      NaN
#
# transac_year_month                                      2018-04
#        category
# amount AIR STANA                                            NaN
#        Accounting, Auditing, and Bookkeeping Services       NaN
#        Advertising Services                                 NaN
#        AeroFlot                                             NaN
#        Agricultural Cooperatives                            NaN

# %%
def do_report(dataframe, currency_int):
    """
    Данная функция делает отчет по аналогии с тем что мыы делали выше, но принимает на вход таблицу и значение валюты
    по которым нужно построить отчет.
    
    Сначала мы создаем пустую таблицу в которую будем добавлять уже посчитанные значения.
    Далее создаем срез из переданной таблицы и создаем отсортированный вектор дат.
    
    После этого начинается цикл, которй бегает по сформированному срезу и берет транзакции по определенной дате и 
    выбирает значения ['transac_year_month','amount','category'].
    
    Далее рассчитаывается .05 и .95 квартиль распределения. По сути мы отбрасываем по 5% максимальных значений и 
    столько же минимальных, тем самым очищая от выбросов, которые могут исказить наши средние значения.
    После того как рассчитали пороги, мы приминяем фильтрацию и получаем очищенную табличку.
    
    Присоединяем ее к созданной в начале с помощью метода pd.concat, разворачиваем и транспонируем.

    """
    
    report = pd.DataFrame()
    currency = currency_int
    df = dataframe[dataframe['currency'] == currency]
    dates = sorted(df['transac_year_month'].unique())


    for date in dates:
        buffer = df[df['transac_year_month'] == date][['transac_year_month','amount','category']].set_index(['transac_year_month','category'])

        # посчитаем значения квартилей по которым будем обрезать наши значния в транзакциях
        low = .05
        high = .95
        quant_df = buffer.quantile([low, high])

        # отфильтруем значения 
        filtered_df = buffer.apply(lambda x: x[(x>quant_df.loc[low,x.name]) & (x < quant_df.loc[high,x.name])], axis=0)
        filtered_df = filtered_df.reset_index().groupby(['transac_year_month','category']).mean()

        # объединяем нашу посчитанную таблицу с главной
        report = pd.concat([report, filtered_df])

    # разворачиваем нашу таблицу, транспонируем и удаляем одну колонку по которой индексировались - непростое комбо!
    report = report.unstack().T
    
    """
    P.S. Пофиксили случай, когда у нас получается слишком маленький отчет и наше отсечение порогов захватывает все записи и у нас
    остается пустой отчет, который приводит к ошибке в следующей функции, которая записывает отчет в excel.
    Я решил написать просто дополнение, а не переписывать функцию полностью.
    """
    if report.shape[0] == 0: # сравниваем длину нашего отчета с нулем. если да, то делаем операции внутри цикла.
        
        report = pd.DataFrame() # обнуляем наш отчет
        
        # для каждой из дат считаем все теже операции, что и выше, но без отсечения выбросов.
        for date in dates:
            buffer = df[df['transac_year_month'] == date][['transac_year_month','amount','category']].set_index(['transac_year_month','category'])
            buffer = buffer.groupby(['transac_year_month','category']).mean()
            report = pd.concat([report, buffer])
            return round(report,2) # возвращаем таблицу с округленными значениями
    else:
        return round(report,2)

# %%
rep = do_report(data,810)
rep
# Out:
# transac_year_month                                          2016-10   2016-11  \
#        category
# amount AIR STANA                                                NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN   2294.42
#        Advertising Services                                 1306.57   2674.30
#        AeroFlot                                            20423.09  12961.51
#        Agricultural Cooperatives                                NaN       NaN
#        Air China                                                NaN       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                               NaN       NaN
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                           12722.28   8273.79
#        Airports, Flying Fields, and Airport Terminals           NaN       NaN
#        Alitalia                                                 NaN  18524.00
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...  16597.50   1103.00
#        Antique Shop                                        16757.56       NaN
#        Aquarium, Seaquarium, Dolphinariums                      NaN    533.33
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                                NaN  13780.00
#        Artist Supply and Craft Stores                           NaN   2031.33
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1116.58   1353.22
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             9500.00    875.00
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              6064.02   3347.08
#        Automotive Service Shops (Non-Dealer)               10424.46   4330.27
#        Automotive Tire Stores                               8876.67   5502.26
#        Automotive Top & Body Shops                              NaN   7955.00
#        Bakeries                                              319.25    416.09
#        Bands, Orchestras & Misc Entertainment                   NaN   5183.33
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                             NaN       NaN
#        Tax Preparation Services                                 NaN       NaN
#        Taxicabs and Limousines                               434.92    305.84
#        Telecommunication Equipment and Telephone Sales      2273.84   3972.32
#        Telecommunication Services, Including Local and...   1094.91   1158.42
#        The Ritz Carlton Hotels                                  NaN       NaN
#        Theatrical Producers (except Motion Pictures) a...   3257.50   3397.61
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                                 NaN       NaN
#        Tourist Attractions and Exhibits                         NaN    878.11
#        Towing Services                                          NaN   4800.00
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     3236.86   1574.11
#        Travel Agencies                                     10709.48   8252.44
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN       NaN
#        Used Merchandise and Secondhand Stores                   NaN   1554.01
#        Utilities-Electric, Gas, Water, and Sanitary         2996.56   3302.84
#        Variety Stores                                       1920.88   1994.77
#        Veterinary Services                                   275.50   1883.75
#        Video Amusement Game Supply                              NaN       NaN
#        Video Game Arcades and Establishments                 283.67   1228.24
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee       12276.22   6662.86
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               1228.40   2127.35
#        Women's Ready-to-Wear Stores                         8233.03   6074.67
#
# transac_year_month                                          2016-12   2017-01  \
#        category
# amount AIR STANA                                                NaN  14061.00
#        Accounting, Auditing, and Bookkeeping Services           NaN    960.00
#        Advertising Services                                 1863.58   1367.67
#        AeroFlot                                            13992.32   8480.99
#        Agricultural Cooperatives                                NaN    702.00
#        Air China                                                NaN       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                           5231.50       NaN
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                            8370.80   6765.98
#        Airports, Flying Fields, and Airport Terminals       3426.95   2100.00
#        Alitalia                                                 NaN   7032.00
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...   3195.56   1889.79
#        Antique Shop                                        10350.00   4000.00
#        Aquarium, Seaquarium, Dolphinariums                   495.00   1566.67
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                            3539.00   3912.50
#        Artist Supply and Craft Stores                       4305.33   2979.25
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1165.43   1323.25
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             8234.37   3734.21
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              3060.31   2903.81
#        Automotive Service Shops (Non-Dealer)                3673.92   2997.01
#        Automotive Tire Stores                               8674.86   4919.11
#        Automotive Top & Body Shops                          2337.50   6653.00
#        Bakeries                                              462.52    381.91
#        Bands, Orchestras & Misc Entertainment               1550.00   1500.00
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN   2446.44
#        Tax Payments                                         6570.32   2896.19
#        Tax Preparation Services                                 NaN       NaN
#        Taxicabs and Limousines                               310.59    281.01
#        Telecommunication Equipment and Telephone Sales      6496.33   5742.97
#        Telecommunication Services, Including Local and...   1012.03   1064.94
#        The Ritz Carlton Hotels                                  NaN       NaN
#        Theatrical Producers (except Motion Pictures) a...   2722.87   2824.76
#        Timeshares                                               NaN   4389.00
#        Tire Retreading & Repair                                 NaN   1800.00
#        Tourist Attractions and Exhibits                      971.52    843.50
#        Towing Services                                          NaN       NaN
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     1400.69    958.02
#        Travel Agencies                                      7724.27   3614.02
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN       NaN
#        Used Merchandise and Secondhand Stores                   NaN   2078.31
#        Utilities-Electric, Gas, Water, and Sanitary         3544.45   2907.48
#        Variety Stores                                       1558.26   1328.02
#        Veterinary Services                                  2731.11   1349.32
#        Video Amusement Game Supply                              NaN       NaN
#        Video Game Arcades and Establishments                 962.77   1064.86
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee        4101.72   3943.72
#        Wig & Toupee Shops                                       NaN   2000.00
#        Women's Accessory and Specialty Stores               2307.11   2518.97
#        Women's Ready-to-Wear Stores                         4550.76   3579.52
#
# transac_year_month                                          2017-02   2017-03  \
#        category
# amount AIR STANA                                           10977.00       NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN       NaN
#        Advertising Services                                 1071.13   1117.51
#        AeroFlot                                             9766.56  11490.96
#        Agricultural Cooperatives                             624.00       NaN
#        Air China                                                NaN       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                               NaN       NaN
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                            7803.96   8457.39
#        Airports, Flying Fields, and Airport Terminals       1750.00   1550.00
#        Alitalia                                                 NaN       NaN
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...   1002.78   1185.00
#        Antique Shop                                             NaN       NaN
#        Aquarium, Seaquarium, Dolphinariums                  1150.00    650.00
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                            2338.00    904.50
#        Artist Supply and Craft Stores                       1099.50   1454.60
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1173.28   1192.10
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             1235.29    916.29
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              3202.50   3896.47
#        Automotive Service Shops (Non-Dealer)                2961.79   3173.67
#        Automotive Tire Stores                               5184.96   9289.87
#        Automotive Top & Body Shops                           270.00   9670.00
#        Bakeries                                              349.80    608.71
#        Bands, Orchestras & Misc Entertainment               3075.00   4397.78
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                         1990.00   2166.04
#        Tax Preparation Services                                 NaN   2599.00
#        Taxicabs and Limousines                               293.85    358.46
#        Telecommunication Equipment and Telephone Sales      6749.47   6200.33
#        Telecommunication Services, Including Local and...   1101.16    870.95
#        The Ritz Carlton Hotels                                  NaN       NaN
#        Theatrical Producers (except Motion Pictures) a...   3332.56   2872.10
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                                 NaN   1250.00
#        Tourist Attractions and Exhibits                      939.76    880.00
#        Towing Services                                          NaN       NaN
#        Trade and Vocational Schools                         8650.00   5900.00
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     1031.98   1145.60
#        Travel Agencies                                      7084.17  10171.88
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN       NaN
#        Used Merchandise and Secondhand Stores                312.67   2845.76
#        Utilities-Electric, Gas, Water, and Sanitary         3557.48   3351.97
#        Variety Stores                                       1380.72   1508.38
#        Veterinary Services                                  1656.86    950.58
#        Video Amusement Game Supply                           530.00       NaN
#        Video Game Arcades and Establishments                1051.39    618.49
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee        3913.00   3178.16
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               1885.26   2966.96
#        Women's Ready-to-Wear Stores                         4765.81   5491.56
#
# transac_year_month                                          2017-04   2017-05  \
#        category
# amount AIR STANA                                                NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN    290.00
#        Advertising Services                                 1783.02   1130.19
#        AeroFlot                                             9601.84   8756.14
#        Agricultural Cooperatives                            1879.50   1440.00
#        Air China                                           25386.00       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                               NaN  12296.00
#        Air Malta                                                NaN  12507.00
#        Airlines and Air Carriers                            8405.97   9094.71
#        Airports, Flying Fields, and Airport Terminals        500.00  11414.54
#        Alitalia                                                 NaN   6397.00
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...   1671.67   1070.83
#        Antique Shop                                          530.14       NaN
#        Aquarium, Seaquarium, Dolphinariums                   797.50   1743.33
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                            1262.57   1117.00
#        Artist Supply and Craft Stores                       2153.06   5091.89
#        Austrian Airlines                                        NaN  15670.00
#        Automated Fuel Dispensers                            1233.55   1279.84
#        Automobile Associations                              3740.00       NaN
#        Automobile Rental Agency                             9232.18    841.76
#        Automotive Paint Shops                                   NaN    420.00
#        Automotive Parts and Accessories Stores              3364.19   2869.73
#        Automotive Service Shops (Non-Dealer)                3486.92   3529.74
#        Automotive Tire Stores                               6113.26   4496.39
#        Automotive Top & Body Shops                          1051.42   5660.00
#        Bakeries                                              748.88    316.86
#        Bands, Orchestras & Misc Entertainment               2735.71   8956.00
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                         1179.07   1254.09
#        Tax Preparation Services                             1699.00       NaN
#        Taxicabs and Limousines                               345.07    331.31
#        Telecommunication Equipment and Telephone Sales      6197.35   6024.36
#        Telecommunication Services, Including Local and...    928.78    961.17
#        The Ritz Carlton Hotels                              9850.00   2300.00
#        Theatrical Producers (except Motion Pictures) a...   2810.66   2846.27
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                             3350.00   1000.00
#        Tourist Attractions and Exhibits                      778.55   1048.91
#        Towing Services                                      1937.00       NaN
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     1306.47   1348.82
#        Travel Agencies                                      6405.22   9021.31
#        Typesetting, Plate Making and Related Services ...       NaN    780.00
#        Typewriter Stores--Sales, Service, and Rentals       1559.00       NaN
#        Used Merchandise and Secondhand Stores               1996.88   2615.57
#        Utilities-Electric, Gas, Water, and Sanitary         3734.02   3708.97
#        Variety Stores                                       1567.34   1481.29
#        Veterinary Services                                   895.67   2222.67
#        Video Amusement Game Supply                           110.00       NaN
#        Video Game Arcades and Establishments                 978.74    939.03
#        W Hotels                                             3366.67       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee        3814.22   3966.04
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               3505.10   2999.78
#        Women's Ready-to-Wear Stores                         5339.64   5209.03
#
# transac_year_month                                          2017-06   2017-07  \
#        category
# amount AIR STANA                                           14092.00  11113.67
#        Accounting, Auditing, and Bookkeeping Services           NaN       NaN
#        Advertising Services                                 1490.12   2049.76
#        AeroFlot                                            10632.52   9061.11
#        Agricultural Cooperatives                            1531.50       NaN
#        Air China                                                NaN       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                           3520.00       NaN
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                            9159.82   9299.54
#        Airports, Flying Fields, and Airport Terminals       3241.67   2943.80
#        Alitalia                                            13516.71  18154.60
#        American Airlines                                        NaN  16341.00
#        Amusement Parks, Circuses, Carnivals, and Fortu...   1372.55   1326.03
#        Antique Shop                                             NaN       NaN
#        Aquarium, Seaquarium, Dolphinariums                  1190.00   2285.00
#        Architectural, Engineering, and Surveying Services       NaN    578.75
#        Art Dealers and Galleries                            1135.00   2438.57
#        Artist Supply and Craft Stores                       2340.50   2468.50
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1074.95   1266.85
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             1015.82   1163.17
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              2710.58   2912.44
#        Automotive Service Shops (Non-Dealer)                3481.87   3497.84
#        Automotive Tire Stores                               3334.24   5764.52
#        Automotive Top & Body Shops                          7168.89    736.67
#        Bakeries                                              453.01    607.72
#        Bands, Orchestras & Misc Entertainment                   NaN   2180.00
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                         1507.12    601.11
#        Tax Preparation Services                                 NaN       NaN
#        Taxicabs and Limousines                               372.30    335.10
#        Telecommunication Equipment and Telephone Sales      4819.31   5465.22
#        Telecommunication Services, Including Local and...    823.10    842.13
#        The Ritz Carlton Hotels                                  NaN  21560.00
#        Theatrical Producers (except Motion Pictures) a...   3305.61   3701.31
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                                 NaN       NaN
#        Tourist Attractions and Exhibits                      910.95    864.04
#        Towing Services                                          NaN       NaN
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     1201.19   1549.00
#        Travel Agencies                                      6792.66   5138.78
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals       2800.00   3900.00
#        Used Merchandise and Secondhand Stores               2634.50    330.00
#        Utilities-Electric, Gas, Water, and Sanitary         3204.20   3441.55
#        Variety Stores                                       1599.00   1421.99
#        Veterinary Services                                  1860.91   2482.89
#        Video Amusement Game Supply                              NaN       NaN
#        Video Game Arcades and Establishments                 758.42    648.56
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee        4017.87   3020.72
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               2930.45   2947.80
#        Women's Ready-to-Wear Stores                         4699.04   3722.10
#
# transac_year_month                                          2017-08   2017-09  \
#        category
# amount AIR STANA                                           10691.00       NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN    720.00
#        Advertising Services                                 1517.03   1700.32
#        AeroFlot                                            10445.11   9230.78
#        Agricultural Cooperatives                                NaN    174.00
#        Air China                                                NaN  18625.00
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                          15402.67  19742.00
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                            9419.91   6902.90
#        Airports, Flying Fields, and Airport Terminals           NaN   1500.00
#        Alitalia                                             7296.00  14803.00
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...   1507.93   1495.54
#        Antique Shop                                             NaN       NaN
#        Aquarium, Seaquarium, Dolphinariums                  1575.00    583.33
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                             987.50    700.00
#        Artist Supply and Craft Stores                       1881.50   1298.38
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1242.53   1265.35
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             7521.88   3178.27
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              3009.63   2896.20
#        Automotive Service Shops (Non-Dealer)                4594.56   3679.32
#        Automotive Tire Stores                               5896.27   8187.68
#        Automotive Top & Body Shops                              NaN       NaN
#        Bakeries                                              250.55    925.76
#        Bands, Orchestras & Misc Entertainment               1725.00   1245.00
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                         1868.85    631.16
#        Tax Preparation Services                                 NaN       NaN
#        Taxicabs and Limousines                               375.32    436.67
#        Telecommunication Equipment and Telephone Sales      4245.92   4749.06
#        Telecommunication Services, Including Local and...    830.38    860.79
#        The Ritz Carlton Hotels                              1800.00   4760.00
#        Theatrical Producers (except Motion Pictures) a...   3269.06   3482.02
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                                 NaN    765.00
#        Tourist Attractions and Exhibits                      840.62    989.38
#        Towing Services                                          NaN       NaN
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     1667.90   1247.63
#        Travel Agencies                                      5595.56   6980.07
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN       NaN
#        Used Merchandise and Secondhand Stores                287.00  10814.73
#        Utilities-Electric, Gas, Water, and Sanitary         3276.94   3731.59
#        Variety Stores                                       1400.79   1513.67
#        Veterinary Services                                  4395.99    652.41
#        Video Amusement Game Supply                           999.00       NaN
#        Video Game Arcades and Establishments                 949.23   1145.28
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee        3512.87   3525.78
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               2489.57   3279.07
#        Women's Ready-to-Wear Stores                         3936.42   4783.55
#
# transac_year_month                                          2017-10   2017-11  \
#        category
# amount AIR STANA                                                NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN       NaN
#        Advertising Services                                 2955.57    533.81
#        AeroFlot                                             9766.24  16065.27
#        Agricultural Cooperatives                                NaN       NaN
#        Air China                                                NaN       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN       NaN
#        Air France                                               NaN       NaN
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                            8633.31  10149.71
#        Airports, Flying Fields, and Airport Terminals       2800.00       NaN
#        Alitalia                                            14509.00       NaN
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...       NaN   3490.00
#        Antique Shop                                             NaN       NaN
#        Aquarium, Seaquarium, Dolphinariums                  1200.00   1400.00
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                                NaN       NaN
#        Artist Supply and Craft Stores                       1577.67   3143.71
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1294.74   1649.94
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             3044.69       NaN
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              3445.82   2189.14
#        Automotive Service Shops (Non-Dealer)                6702.44   4720.75
#        Automotive Tire Stores                               7645.14  11775.00
#        Automotive Top & Body Shops                          6915.00       NaN
#        Bakeries                                              485.36    150.00
#        Bands, Orchestras & Misc Entertainment                   NaN       NaN
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                         1950.24   6894.73
#        Tax Preparation Services                                 NaN       NaN
#        Taxicabs and Limousines                               509.65    342.70
#        Telecommunication Equipment and Telephone Sales      3883.21   2093.00
#        Telecommunication Services, Including Local and...   1049.43    815.60
#        The Ritz Carlton Hotels                                  NaN       NaN
#        Theatrical Producers (except Motion Pictures) a...   3198.00   5139.91
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                             1389.00       NaN
#        Tourist Attractions and Exhibits                      745.83   2500.00
#        Towing Services                                          NaN       NaN
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN       NaN
#        Transportation Services-not elsewhere classified     1127.36   2883.22
#        Travel Agencies                                      5932.91   6113.05
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN       NaN
#        Used Merchandise and Secondhand Stores               2346.50       NaN
#        Utilities-Electric, Gas, Water, and Sanitary         3769.07   6240.00
#        Variety Stores                                       1871.77   1190.47
#        Veterinary Services                                  9313.00   1749.67
#        Video Amusement Game Supply                              NaN       NaN
#        Video Game Arcades and Establishments                1613.80       NaN
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN       NaN
#        Wholesale Club with or without membership fee        3588.00   8530.00
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               3666.73   4258.17
#        Women's Ready-to-Wear Stores                         6139.80   5924.88
#
# transac_year_month                                          2017-12   2018-01  \
#        category
# amount AIR STANA                                                NaN       NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN       NaN
#        Advertising Services                                  191.31    293.31
#        AeroFlot                                            11272.70  12295.00
#        Agricultural Cooperatives                                NaN       NaN
#        Air China                                                NaN       NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN  14990.00
#        Air France                                           2085.00       NaN
#        Air Malta                                                NaN       NaN
#        Airlines and Air Carriers                           10265.83  10642.91
#        Airports, Flying Fields, and Airport Terminals           NaN       NaN
#        Alitalia                                                 NaN       NaN
#        American Airlines                                        NaN       NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...       NaN   1525.00
#        Antique Shop                                             NaN       NaN
#        Aquarium, Seaquarium, Dolphinariums                      NaN   3032.68
#        Architectural, Engineering, and Surveying Services       NaN       NaN
#        Art Dealers and Galleries                                NaN       NaN
#        Artist Supply and Craft Stores                           NaN    350.00
#        Austrian Airlines                                        NaN       NaN
#        Automated Fuel Dispensers                            1527.79   1318.16
#        Automobile Associations                                  NaN       NaN
#        Automobile Rental Agency                             1550.00    775.80
#        Automotive Paint Shops                                   NaN       NaN
#        Automotive Parts and Accessories Stores              1414.81   3092.78
#        Automotive Service Shops (Non-Dealer)                3284.16   2759.56
#        Automotive Tire Stores                               1189.00       NaN
#        Automotive Top & Body Shops                              NaN       NaN
#        Bakeries                                              199.00    169.80
#        Bands, Orchestras & Misc Entertainment               8025.00   1125.00
# ...                                                             ...       ...
#        Taj Hotels International                                 NaN       NaN
#        Tax Payments                                         3932.10   1377.90
#        Tax Preparation Services                                 NaN       NaN
#        Taxicabs and Limousines                               362.71    355.49
#        Telecommunication Equipment and Telephone Sales      5230.88   1939.08
#        Telecommunication Services, Including Local and...   1400.67   1262.42
#        The Ritz Carlton Hotels                                  NaN       NaN
#        Theatrical Producers (except Motion Pictures) a...   5262.86   2279.17
#        Timeshares                                               NaN       NaN
#        Tire Retreading & Repair                                 NaN       NaN
#        Tourist Attractions and Exhibits                     1695.21    525.00
#        Towing Services                                          NaN       NaN
#        Trade and Vocational Schools                             NaN       NaN
#        Trailer Parks and Campgrounds                            NaN   1400.00
#        Transportation Services-not elsewhere classified     1779.67   1699.83
#        Travel Agencies                                     16774.28   4063.30
#        Typesetting, Plate Making and Related Services ...       NaN       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN       NaN
#        Used Merchandise and Secondhand Stores                   NaN       NaN
#        Utilities-Electric, Gas, Water, and Sanitary         3278.21   2956.26
#        Variety Stores                                       2482.96   1969.32
#        Veterinary Services                                  3587.14   1401.00
#        Video Amusement Game Supply                              NaN       NaN
#        Video Game Arcades and Establishments                1746.91    915.77
#        W Hotels                                                 NaN       NaN
#        Watch, Clock, and Jewelry Repair Shops              18369.00       NaN
#        Wholesale Club with or without membership fee        6133.33   2055.50
#        Wig & Toupee Shops                                       NaN       NaN
#        Women's Accessory and Specialty Stores               3555.40   5061.33
#        Women's Ready-to-Wear Stores                         3342.75   4795.25
#
# transac_year_month                                          2018-02  2018-03  \
#        category
# amount AIR STANA                                                NaN      NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN      NaN
#        Advertising Services                                  339.00   339.64
#        AeroFlot                                            11299.33  7031.71
#        Agricultural Cooperatives                                NaN      NaN
#        Air China                                                NaN      NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN      NaN
#        Air France                                               NaN      NaN
#        Air Malta                                                NaN      NaN
#        Airlines and Air Carriers                            5953.20  9616.89
#        Airports, Flying Fields, and Airport Terminals           NaN      NaN
#        Alitalia                                                 NaN      NaN
#        American Airlines                                        NaN      NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...       NaN      NaN
#        Antique Shop                                             NaN      NaN
#        Aquarium, Seaquarium, Dolphinariums                      NaN      NaN
#        Architectural, Engineering, and Surveying Services       NaN      NaN
#        Art Dealers and Galleries                                NaN      NaN
#        Artist Supply and Craft Stores                           NaN      NaN
#        Austrian Airlines                                        NaN      NaN
#        Automated Fuel Dispensers                            1640.01   840.21
#        Automobile Associations                                  NaN      NaN
#        Automobile Rental Agency                             8249.42      NaN
#        Automotive Paint Shops                                   NaN      NaN
#        Automotive Parts and Accessories Stores               731.75  2033.54
#        Automotive Service Shops (Non-Dealer)                4063.56  4332.60
#        Automotive Tire Stores                                   NaN    80.00
#        Automotive Top & Body Shops                              NaN      NaN
#        Bakeries                                              890.70   155.62
#        Bands, Orchestras & Misc Entertainment               3000.00      NaN
# ...                                                             ...      ...
#        Taj Hotels International                                 NaN      NaN
#        Tax Payments                                         2487.56  1400.00
#        Tax Preparation Services                                 NaN      NaN
#        Taxicabs and Limousines                               355.96   368.95
#        Telecommunication Equipment and Telephone Sales      1502.51  1552.72
#        Telecommunication Services, Including Local and...    692.81  1097.80
#        The Ritz Carlton Hotels                                  NaN      NaN
#        Theatrical Producers (except Motion Pictures) a...   6633.67  1340.00
#        Timeshares                                               NaN      NaN
#        Tire Retreading & Repair                                 NaN      NaN
#        Tourist Attractions and Exhibits                     1050.00  1926.00
#        Towing Services                                          NaN      NaN
#        Trade and Vocational Schools                             NaN      NaN
#        Trailer Parks and Campgrounds                            NaN   700.00
#        Transportation Services-not elsewhere classified      170.00  1157.50
#        Travel Agencies                                     11042.71  5872.96
#        Typesetting, Plate Making and Related Services ...       NaN      NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN      NaN
#        Used Merchandise and Secondhand Stores               1069.00      NaN
#        Utilities-Electric, Gas, Water, and Sanitary         3525.16  3961.79
#        Variety Stores                                       1245.29  1113.10
#        Veterinary Services                                   250.00  2999.07
#        Video Amusement Game Supply                              NaN      NaN
#        Video Game Arcades and Establishments                3931.33      NaN
#        W Hotels                                                 NaN      NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN      NaN
#        Wholesale Club with or without membership fee         442.00   367.00
#        Wig & Toupee Shops                                       NaN      NaN
#        Women's Accessory and Specialty Stores                373.50  1200.00
#        Women's Ready-to-Wear Stores                         5228.12  5874.35
#
# transac_year_month                                          2018-04
#        category
# amount AIR STANA                                                NaN
#        Accounting, Auditing, and Bookkeeping Services           NaN
#        Advertising Services                                     NaN
#        AeroFlot                                                 NaN
#        Agricultural Cooperatives                                NaN
#        Air China                                                NaN
#        Air Conditioning and Refrigeration Repair Shops          NaN
#        Air France                                               NaN
#        Air Malta                                                NaN
#        Airlines and Air Carriers                                NaN
#        Airports, Flying Fields, and Airport Terminals           NaN
#        Alitalia                                                 NaN
#        American Airlines                                        NaN
#        Amusement Parks, Circuses, Carnivals, and Fortu...       NaN
#        Antique Shop                                             NaN
#        Aquarium, Seaquarium, Dolphinariums                      NaN
#        Architectural, Engineering, and Surveying Services       NaN
#        Art Dealers and Galleries                                NaN
#        Artist Supply and Craft Stores                           NaN
#        Austrian Airlines                                        NaN
#        Automated Fuel Dispensers                                NaN
#        Automobile Associations                                  NaN
#        Automobile Rental Agency                                 NaN
#        Automotive Paint Shops                                   NaN
#        Automotive Parts and Accessories Stores                  NaN
#        Automotive Service Shops (Non-Dealer)                    NaN
#        Automotive Tire Stores                                   NaN
#        Automotive Top & Body Shops                              NaN
#        Bakeries                                                 NaN
#        Bands, Orchestras & Misc Entertainment                   NaN
# ...                                                             ...
#        Taj Hotels International                                 NaN
#        Tax Payments                                             NaN
#        Tax Preparation Services                                 NaN
#        Taxicabs and Limousines                                  NaN
#        Telecommunication Equipment and Telephone Sales          NaN
#        Telecommunication Services, Including Local and...       NaN
#        The Ritz Carlton Hotels                                  NaN
#        Theatrical Producers (except Motion Pictures) a...  30000.00
#        Timeshares                                               NaN
#        Tire Retreading & Repair                                 NaN
#        Tourist Attractions and Exhibits                         NaN
#        Towing Services                                          NaN
#        Trade and Vocational Schools                             NaN
#        Trailer Parks and Campgrounds                            NaN
#        Transportation Services-not elsewhere classified         NaN
#        Travel Agencies                                          NaN
#        Typesetting, Plate Making and Related Services ...       NaN
#        Typewriter Stores--Sales, Service, and Rentals           NaN
#        Used Merchandise and Secondhand Stores                   NaN
#        Utilities-Electric, Gas, Water, and Sanitary         7632.68
#        Variety Stores                                        156.38
#        Veterinary Services                                      NaN
#        Video Amusement Game Supply                              NaN
#        Video Game Arcades and Establishments                    NaN
#        W Hotels                                                 NaN
#        Watch, Clock, and Jewelry Repair Shops                   NaN
#        Wholesale Club with or without membership fee            NaN
#        Wig & Toupee Shops                                       NaN
#        Women's Accessory and Specialty Stores                   NaN
#        Women's Ready-to-Wear Stores                             NaN
#
# [316 rows x 19 columns]

# %% [markdown]
# Проверим. Работает!

# %% [markdown]
# Осталось только проделать это все для каждой категории транзакций, записать на отдельный лист и записать в эксельник.<br>
# Ниже я написал функуцию, которая циклично добавляет табличку на новыый лист с названием этой таблицы.

# %%
def write_excel_cyclicaly(dataframe, dataframe_name):
    import openpyxl
    """
    Эта функция циклично добавляет табличку на новыый лист с названием этой таблицы, используя конструкцию with.
    
    """

    with pd.ExcelWriter('results/report_978.xlsx', engine='openpyxl') as writer:
        writer.book = book
        writer.sheets = dict((ws.title, ws) for ws in book.worksheets)    

        dataframe.to_excel(writer, '{}'.format(str(dataframe_name)))
        writer.save()

# %% [markdown]
# Осталось немного. А именно нам нужно создать/инициализировать пустой файл эксель отчета и произвести в него запись,<br>
# получившихся таблиц.

# %%
# определяем транзакционные категории конкретно для выбранного нами кода валюты
trx_cats = data[data['currency'] == 978]['trx_category'].unique()

# создаем/инициализируем файл 
import openpyxl
filepath = "results/"
book = openpyxl.Workbook()
book.save(filepath+'report_978.xlsx')

# цикл создания отчетов и записи в эксель файл
for trx_cat in trx_cats:
    report = do_report(data[data['trx_category'] == trx_cat], 978)
    write_excel_cyclicaly(report, '{}'.format(trx_cat))

# %% [markdown]
# ## 5. Отчет по оттоку.

# %% [markdown]
# Отток, или **churn** можно определять по-разному, например в зависимости от периода.<br>
# Так же понятие оттока довольно тесно связано с удержанием или **retention**. Это напротив, сколько людей у нас остается на протяжении из месяца в месяц работы сервиса/подписки и приносит деньги.
# Давайте посчитаем классический месячныый отток, тоесть проверим сколько людей уходили в текущий месяц, сравнивая его с предыдущим.

# %%
data.head(3)

# %%
"""
В этом куске кода мы будем искать оттекших пользователей тоесть cl_id, которых нет в этом месяце, но есть в прошлом. 
С точки зрения банковской деятельности это вобщем-то обосновано и у нас как раз транзакционные данные. В случае если 
это какой-то продукт, то возможно стоит увеличить окно в зависимости от бизнес процессов.

`del previous, current` - Строчка которая, удаляет вектора 
Если вылезла ошибка, то нужно просто закомментировать, а потом раскомментировать, чтобы первая ячейка была всегда np.nan, 
потому что мы считаем отношение к прошлом месяцу, данными к которым мы еще не обладаем.

1) Используем цикл с возможностью отловить ошибку: try ... except, который позволит нам не завершать цикл если вылезет ошибка.
А ошибка у нас вылезает в случае, если у нас нет значения за прошлый период. 
2) Находим вектор айдишников пользователей в текущем месяце.
3) Находим пересечение с прошлым месяцем, точнее инфертированное пересечение или те значения, которых нет в текущем месяце, 
сравнивая с предыдущим. У нас возвращается вектор True/False значений.
P.S. На этом этапе у нас появляется ошибка в когда мы сравниваем первый месяц с прыдыдущего, которого у нас нет. У нас возникает
ошибка, которую мы отлавливает и исполняем код в после except.
4) Мы индексируемся, используя вектор True/False значений, получая только значения айдишников пользователей.
5) Считаем длину вектора или по-другому количество "оттекших" пользователей.
6) Переназначаем текущий вектор айдишников на прошлый период, чтобы сравнивать уже со следующим периодом.

"""

churn_array = []
if 'previous' in globals(): del(previous)
for month in sorted(data['transac_year_month'].unique()):
    # 1
    try:
        # 2
        current = data[data['transac_year_month'] == month]['cl_id'].unique()
        # 3
        churned_idx = np.isin(previous, current, invert=False) 
        # 4
        churned = previous[churned_idx] 
        # 5
        churn_array.append(len(churned))
        # 6
        previous = current
    except NameError:
        churn_array.append(np.nan)
        # 7
        previous = data[data['transac_year_month'] == month]['cl_id'].unique()

# %%
churn_table = pd.DataFrame({'months':sorted(data['transac_year_month'].unique()),
                            'churn':churn_array
                           }, columns=['months','churn'])

churn_table
# Out:
#      months   churn
# 0   2016-10     NaN
# 1   2016-11   430.0
# 2   2016-12  1569.0
# 3   2017-01  2913.0
# 4   2017-02  2330.0
# 5   2017-03  1992.0
# 6   2017-04  1796.0
# 7   2017-05  2291.0
# 8   2017-06  2451.0
# 9   2017-07  2628.0
# 10  2017-08  2656.0
# 11  2017-09  1893.0
# 12  2017-10  1030.0
# 13  2017-11   361.0
# 14  2017-12   267.0
# 15  2018-01   209.0
# 16  2018-02   174.0
# 17  2018-03   149.0
# 18  2018-04    48.0

# %% [markdown]
# Запишем наш файл.

# %%
churn_table.to_csv('results/churn.csv',index=False)

# %% [markdown]
# Построим минимальный график, чтобы немного затронуть нашу следующую тему- визуализацию.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(15,5))
churn_table['churn'].plot()

plt.xlabel('dates', fontsize=14)
ax = plt.gca()
plt.xticks(np.arange(0, len(dates), 1.0))
ax.set_xticklabels(churn_table['months'], fontsize=12, rotation=30)
plt.tight_layout()

plt.ylabel('ids')
plt.xlabel('dates')
plt.title('Users churned', fontsize=14)
plt.savefig('results/churn.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Посылаем файлы на почту.

# %% [markdown]
# Эта монстр функция посылает прогноз по почте указаным адресам.<br>
# Не обязатально понимать сразу все что написано внутри, можно разобрать это по-тихоньку по этапам.

# %%
def send_email(mail_from, password, subject):  

    """
    Эта функция посылает файл/файлы по почте указаным адресам.
    
    1) Константы и переменные которые остаются неизменными, либо меняются нечасто.
    2) Параметры для письма.
    3) Список всех путей до документов, которые нужно послать.
    4) Цикл для присоединения документов к письму.
    5) Цикл для посылки письма. Тестирует на соединение и посылает письмо.
    
    """
    import smtplib, os, sys
    from email.mime.multipart import MIMEMultipart
    from email.mime.text import MIMEText
    from email.mime.base import MIMEBase
    from email import encoders
    
    # 1
    RESULTS_PATH = 'results'
    SENDER = str(mail_from)
    PASSWORD = str(password)
    RECEPIENTS = 'badashca@gmail.com'
    #COMMASPACE = ', '
    
    # 2
    outer = MIMEMultipart()
    outer['Subject'] = subject
    outer['To'] =  RECEPIENTS #COMMASPACE.join(RECEPIENTS) 
    outer['From'] = SENDER
    #outer.preamble = ''

    # 3
    ATTACHEMENTS = ['report.xlsx',
                    'churn.csv',
                    'churn.png'] 

    # 4
    for file in ATTACHEMENTS:
        try:
            with open(file, 'rb') as fp:
                msg = MIMEBase('application', "octet-stream")
                msg.set_payload(fp.read())
            encoders.encode_base64(msg)
            msg.add_header('Content-Disposition', 'attachment', filename=os.path.basename(file))
            outer.attach(msg)
        except:
            print("Unable to open one of the attachments. Error: ", sys.exc_info()[0])
            raise

    COMPOSED = outer.as_string()

    # 5
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as s:
            s.ehlo()
            s.starttls()
            s.ehlo()
            s.login(SENDER, PASSWORD)
            s.sendmail(SENDER, RECEPIENTS, COMPOSED)
            s.close()
    except:
        print("Unable to send the email. Error: ", sys.exc_info()[0])
        raise

# %% [markdown]
# Функция не быстрая, немного подумает, но все отработает.<br>
# При желаниии ее можно немного переделать, например переместив возможность задавать пути до файлов как аргументы для самой функции.

# %%
send_email('badashca@gmail.com', 'XXXXXXXXXXX', 'мой первый отчет')

# %% [markdown]
# ### Домашнее задание

# %% [markdown]
# Практическая часть домашнего задания на этой неделе будет довольно объемным:
#
# 1) Нужно поиграться с ноутбуком и подкрутить скрипт для подобного отчета **по долларам США** и еще одной валюте на выбор. Смело копируйте этот ноутбук и сделайте так, чтобы **отчет о транзакциях** был **в одном файле экселя** и пошлите себе **файлик на почту**.<br>
#
# 2) Отток мы посчитали, как на счет посчитать retention? Или сколько пользователей в текущем месяце присутствуют в прошлом месяце. (по сути это ***обратная*** или ***инвертированная задача*** для той что уже мы посчитали.)
#
# 3) И свободная часть: **реализовать похожий скрипт для своих нужд** и со своими данными.<br>
#
# **P.S.** В функции `send_email` можете указать несколько адресатов в поле `RECEPIENTS` через запятую.
# В таком случае нужно будет раскомментировать параметр `COMMASPACE = ', '` (убрать решетку до него) и заменить `RECEPIENTS` на `COMMASPACE.join(RECEPIENTS)` так же без решетки.
